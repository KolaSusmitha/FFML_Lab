# %% [markdown]
# <a href="https://colab.research.google.com/github/KolaSusmitha/FMML_Lab/blob/main/FMML_Aug'22_M9_L2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Foundation of Modern Machine Learning
# ## Module 9: Neural Networks
# ## Lab 2: Using MLP for multiclass classification
# #### Module Coordinator: Shantanu Agrawal

# %% [markdown]
# Till now, we got to know what is MLP, how it can be used for classification. We have done the single class classification in the previous lab session.
#
# In this notebook we will try to use an MLP for multiclass classification on the iris dataset.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Data preparation

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Load the iris dataset
iris = load_iris()
X = iris['data']
y = iris['target']
names = iris['target_names']
feature_names = iris['feature_names']

# Scale data to have mean 0 and variance 1
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the data set into training and testing
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=2)

# %% [markdown]
# # Visualising dataset

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
for target, target_name in enumerate(names):
    X_plot = X[y == target]
    ax1.plot(X_plot[:, 0], X_plot[:, 1],
             linestyle='none',
             marker='o',
             label=target_name)
ax1.set_xlabel(feature_names[0])
ax1.set_ylabel(feature_names[1])
ax1.axis('equal')
ax1.legend();

for target, target_name in enumerate(names):
    X_plot = X[y == target]
    ax2.plot(X_plot[:, 2], X_plot[:, 3],
             linestyle='none',
             marker='o',
             label=target_name)
ax2.set_xlabel(feature_names[2])
ax2.set_ylabel(feature_names[3])
ax2.axis('equal')
ax2.legend();

# %% [markdown]
# # Observing the dataset
#
# Thus, we can observe the dataset and see that there are *3 classes, setosa, versicolor, and virginica*.
#
# There are *4 features, sepal width, sepal length, petal width, petal length*.

# %% [markdown]
# # MLP for multiclass classification

# %%
import torch
import torch.nn.functional as F
import torch.nn as nn
from torch.autograd import Variable
import tqdm

# %%
# Defining the model architecture
class Model(nn.Module):
    def __init__(self, input_dim):
        super(Model, self).__init__()
        self.layer1 = nn.Linear(input_dim, 50)
        self.layer2 = nn.Linear(50, 50)
        self.layer3 = nn.Linear(50, 3)

    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        x = F.softmax(self.layer3(x), dim=1)
        return x

# %%
# Instantiating the model, using Adam optimiser, and Cross Entropy Loss, which is quite commonlu used for classification tasks.
model     = Model(X_train.shape[1])
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
loss_fn   = nn.CrossEntropyLoss()

# %% [markdown]
# # Train the model

# %%
# Train for 100 epochs
EPOCHS  = 100
X_train = torch.from_numpy(X_train).float()
X_test= torch.from_numpy(X_test).float()
y_test = torch.from_numpy(y_test)
y_train = torch.from_numpy(y_train)


loss_list     = np.zeros((EPOCHS,))
accuracy_list = np.zeros((EPOCHS,))

for epoch in tqdm.trange(EPOCHS):
    y_pred = model(X_train)
    loss = loss_fn(y_pred, y_train)
    loss_list[epoch] = loss.item()

    # Zero gradients
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    with torch.no_grad():
        y_pred = model(X_test)
        correct = (torch.argmax(y_pred, dim=1) == y_test).type(torch.FloatTensor)
        accuracy_list[epoch] = correct.mean()
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 381.87it/s]

# %% [markdown]
# # Plot training progress

# %%
fig, (ax1, ax2) = plt.subplots(2, figsize=(12, 6), sharex=True)

ax1.plot(accuracy_list)
ax1.set_ylabel("validation accuracy")
ax2.plot(loss_list)
ax2.set_ylabel("validation loss")
ax2.set_xlabel("epochs");

# %% [markdown]
# # Experiment with the neural network architecture
#
#
# 1.   Try changing the number of hidden layers.
# 2.   Try changing the number of neurons in the hidden layer.
# 3.   Try using a different activation function.
#
#
#
#
# Can you observe any changes?

# %%
class ModifiedModel(nn.Module):
    def __init__(self, input_dim):
        super(ModifiedModel, self).__init__()
        self.layer1 = nn.Linear(input_dim, 100)  # Increase neurons to 100
        self.layer2 = nn.Linear(100, 100)        # Increase neurons to 100
        self.layer3 = nn.Linear(100, 100)        # Adding one more hidden layer with 100 neurons
        self.layer4 = nn.Linear(100, 3)          # Output layer remains the same

    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        x = F.relu(self.layer3(x))  # Using ReLU for hidden layers
        x = F.softmax(self.layer4(x), dim=1)
        return x

# %%
class ModifiedModel(nn.Module):
    def __init__(self, input_dim):
        super(ModifiedModel, self).__init__()
        self.layer1 = nn.Linear(input_dim, 100)  # Increase neurons to 100
        self.layer2 = nn.Linear(100, 100)        # Increase neurons to 100
        self.layer3 = nn.Linear(100, 3)          # Output layer remains the same

    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))  # Using ReLU for hidden layers
        x = F.softmax(self.layer3(x), dim=1)
        return x

# %%
class ModifiedModel(nn.Module):
    def __init__(self, input_dim):
        super(ModifiedModel, self).__init__()
        self.layer1 = nn.Linear(input_dim, 100)  # Keep neurons at 50
        self.layer2 = nn.Linear(100, 100)        # Keep neurons at 50
        self.layer3 = nn.Linear(100, 3)          # Output layer remains the same

    def forward(self, x):
        x = F.tanh(self.layer1(x))  # Using Tanh for hidden layers
        x = F.tanh(self.layer2(x))  # Using Tanh for hidden layers
        x = F.softmax(self.layer3(x), dim=1)
        return x

# %%
# Training the model with one additional hidden layer
modified_model_1 = ModifiedModel(X_train.shape[1])
optimizer_1 = torch.optim.Adam(modified_model_1.parameters(), lr=0.001)
loss_list_1 = np.zeros((EPOCHS,))
accuracy_list_1 = np.zeros((EPOCHS,))

for epoch in tqdm.trange(EPOCHS):
    y_pred = modified_model_1(X_train)
    loss = loss_fn(y_pred, y_train)
    loss_list_1[epoch] = loss.item()

    # Zero gradients
    optimizer_1.zero_grad()
    loss.backward()
    optimizer_1.step()

    with torch.no_grad():
        y_pred = modified_model_1(X_test)
        correct = (torch.argmax(y_pred, dim=1) == y_test).type(torch.FloatTensor)
        accuracy_list_1[epoch] = correct.mean()

# Training the model with increased neurons in hidden layers
modified_model_2 = ModifiedModel(X_train.shape[1])
optimizer_2 = torch.optim.Adam(modified_model_2.parameters(), lr=0.001)
loss_list_2 = np.zeros((EPOCHS,))
accuracy_list_2 = np.zeros((EPOCHS,))

for epoch in tqdm.trange(EPOCHS):
    y_pred = modified_model_2(X_train)
    loss = loss_fn(y_pred, y_train)
    loss_list_2[epoch] = loss.item()

    # Zero gradients
    optimizer_2.zero_grad()
    loss.backward()
    optimizer_2.step()

    with torch.no_grad():
        y_pred = modified_model_2(X_test)
        correct = (torch.argmax(y_pred, dim=1) == y_test).type(torch.FloatTensor)
        accuracy_list_2[epoch] = correct.mean()

# Training the model with Tanh activation function for hidden layers
modified_model_3 = ModifiedModel(X_train.shape[1])
optimizer_3 = torch.optim.Adam(modified_model_3.parameters(), lr=0.001)
loss_list_3 = np.zeros((EPOCHS,))
accuracy_list_3 = np.zeros((EPOCHS,))

for epoch in tqdm.trange(EPOCHS):
    y_pred = modified_model_3(X_train)
    loss = loss_fn(y_pred, y_train)
    loss_list_3[epoch] = loss.item()

    # Zero gradients
    optimizer_3.zero_grad()
    loss.backward()
    optimizer_3.step()

    with torch.no_grad():
        y_pred = modified_model_3(X_test)
        correct = (torch.argmax(y_pred, dim=1) == y_test).type(torch.FloatTensor)
        accuracy_list_3[epoch] = correct.mean()
# Out:
# ...
# 100%|██████████| 100/100 [00:00<00:00, 540.25it/s]
